# %%
import pandas as pd
# Loading and assigning the dataset as data_f
data_f = pd.read_csv("Downloads/travel+reviews/tripadvisor_review.csv")
# Checking the features of the dataset
print("Dataset shape:", data_f.shape)
print("Columns:", data_f.columns.tolist())
# Out:
# Dataset shape: (980, 11)
# Columns: ['User ID', 'Category 1', 'Category 2', 'Category 3', 'Category 4', 'Category 5', 'Category 6', 'Category 7', 'Category 8', 'Category 9', 'Category 10']

# %%
# Removing unnecessary columns like user ids
data_f = data_f.drop(columns=['User ID'])
data_f.columns
# Out:
# Index(['Category 1', 'Category 2', 'Category 3', 'Category 4', 'Category 5',
#        'Category 6', 'Category 7', 'Category 8', 'Category 9', 'Category 10'],
#       dtype='object')

# %%
# Showing first 10 columns of dataset
data_f.head(10)
# Out:
#    Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 0        0.93        1.80        2.29        0.62        0.80        2.42
# 1        1.02        2.20        2.66        0.64        1.42        3.18
# 2        1.22        0.80        0.54        0.53        0.24        1.54
# 3        0.45        1.80        0.29        0.57        0.46        1.52
# 4        0.51        1.20        1.18        0.57        1.54        2.02
# 5        0.99        1.28        0.72        0.27        0.74        1.26
# 6        0.90        1.36        0.26        0.32        0.86        1.58
# 7        0.74        1.40        0.22        0.41        0.82        1.50
# 8        1.12        1.76        1.04        0.64        0.82        2.14
# 9        0.70        1.36        0.22        0.26        1.50        1.54
#
#    Category 7  Category 8  Category 9  Category 10
# 0        3.19        2.79        1.82         2.42
# 1        3.21        2.63        1.86         2.32
# 2        3.18        2.80        1.31         2.50
# 3        3.18        2.96        1.57         2.86
# 4        3.18        2.78        1.18         2.54
# 5        3.17        2.89        1.66         3.66
# 6        3.17        2.66        1.22         3.22
# 7        3.17        2.81        1.54         2.88
# 8        3.18        2.79        1.41         2.54
# 9        3.17        2.82        2.24         3.12

# %%
# Showing last 10 columns
data_f.tail(10)
# Out:
#      Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 970        0.58        1.96        0.24        0.47        1.04        1.74
# 971        1.28        1.24        0.14        0.55        0.62        2.26
# 972        1.22        1.16        0.38        1.55        0.40        1.24
# 973        0.38        1.96        0.19        0.48        1.14        2.14
# 974        1.02        2.44        1.89        0.47        1.76        2.50
# 975        0.74        1.12        0.30        0.53        0.88        1.38
# 976        1.25        0.92        1.12        0.38        0.78        1.68
# 977        0.61        1.32        0.67        0.43        1.30        1.78
# 978        0.93        0.20        0.13        0.43        0.30        0.40
# 979        0.93        0.56        1.13        0.51        1.34        2.36
#
#      Category 7  Category 8  Category 9  Category 10
# 970        3.18        2.70        1.57         2.62
# 971        3.18        2.86        2.46         2.54
# 972        3.18        2.82        1.92         2.54
# 973        3.18        2.78        1.54         2.58
# 974        3.19        2.66        1.73         2.48
# 975        3.17        2.78        0.99         3.20
# 976        3.18        2.79        1.34         2.80
# 977        3.17        2.81        1.34         3.02
# 978        3.18        2.98        1.12         2.46
# 979        3.18        2.87        1.34         2.40

# %%
# Identifying diplicates
dups = data_f.duplicated().sum()
print(f"\nDuplicate rows: {dups}")
# Out:
# Duplicate rows: 39

# %%
# Checking data type
data_f.dtypes
# Out:
# Category 1     float64
# Category 2     float64
# Category 3     float64
# Category 4     float64
# Category 5     float64
# Category 6     float64
# Category 7     float64
# Category 8     float64
# Category 9     float64
# Category 10    float64
# dtype: object

# %%
print("Duplicated rows:",data_f.duplicated().sum())
# Out:
# Duplicated rows: 39

# %%
# Checking for nulls or missing values
data_f.isnull().sum()
# Out:
# Category 1     0
# Category 2     0
# Category 3     0
# Category 4     0
# Category 5     0
# Category 6     0
# Category 7     0
# Category 8     0
# Category 9     0
# Category 10    0
# dtype: int64

# %%
# Checking summary statistics of dataset
data_f.describe(include='all').T
# Out:
#              count      mean       std   min   25%   50%     75%   max
# Category 1   980.0  0.893194  0.326912  0.34  0.67  0.83  1.0200  3.22
# Category 2   980.0  1.352612  0.478280  0.00  1.08  1.28  1.5600  3.64
# Category 3   980.0  1.013306  0.788607  0.13  0.27  0.82  1.5725  3.62
# Category 4   980.0  0.532500  0.279731  0.15  0.41  0.50  0.5800  3.44
# Category 5   980.0  0.939735  0.437430  0.06  0.64  0.90  1.2000  3.30
# Category 6   980.0  1.842898  0.539538  0.14  1.46  1.80  2.2000  3.76
# Category 7   980.0  3.180939  0.007824  3.16  3.18  3.18  3.1800  3.21
# Category 8   980.0  2.835061  0.137505  2.42  2.74  2.82  2.9100  3.39
# Category 9   980.0  1.569439  0.364629  0.74  1.31  1.54  1.7600  3.17
# Category 10  980.0  2.799224  0.321380  2.14  2.54  2.78  3.0400  3.66

# %%
# Plotting Histogram for each category
import matplotlib.pyplot as plt
features = data_f.columns.tolist()
for feature in features:
    plt.figure(figsize=(6,3))
    plt.hist(data_f[feature].dropna(), bins=20)
    plt.title(f'Histogram: {feature}')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()

# %%
# Plotting heatmap to correlation 
plt.figure(figsize=(8,6))
corr = data_f.corr()
plt.imshow(corr, aspect='auto', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(features)), features, rotation=90)
plt.yticks(range(len(features)), features)
plt.title('Correlation matrix (heatmap)')
plt.tight_layout()
plt.show()

# %%
# Boxplots
for col in features:
    plt.figure(figsize=(6,2.5))
    plt.boxplot(data_f[col].dropna(), vert=False)
    plt.title(f'Boxplot: {col}')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()

# %%
# Pre-processing

from sklearn.preprocessing import StandardScaler

data_f = data_f.astype(float)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(data_f)

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

results = []
k_inertia = []; 
k_sil = []; 
k_range = range(3,8)
for k in k_range:
    k_means_model = KMeans(n_clusters=k, random_state=42, n_init=10)
    k_labels = k_means_model.fit_predict(X_scaled)
    k_inertia = k_means_model.inertia_
    k_sil = silhouette_score(X_scaled, k_labels)
    
    results.append([k, k_inertia, k_sil])

results_df = pd.DataFrame(results, columns=["k", "Inertia", "Silhouette Score"])
print(results_df)

best_k = list(k_range)[int(np.argmax(k_sil))]
print("Best k by silhouette:", best_k)

plt.figure(figsize=(6,3)); plt.plot(list(K_range), inertia, marker='o'); plt.title('Elbow (inertia)'); plt.xlabel('k'); plt.ylabel('Inertia'); plt.tight_layout(); plt.show()
plt.figure(figsize=(6,3)); plt.plot(list(K_range), sil_scores, marker='o'); plt.title('Silhouette by k'); plt.xlabel('k'); plt.ylabel('Silhouette'); plt.tight_layout(); plt.show()
# Out:
#    k      Inertia  Silhouette Score
# 0  2  7767.399323          0.213154
# 1  3  7128.449834          0.139548
# 2  4  6464.314376          0.150530
# 3  5  6003.328707          0.159216
# 4  6  5613.132662          0.140023
# 5  7  5308.609075          0.136600
# 6  8  5062.444778          0.136219
# Best k by silhouette: 2

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
centroids_pca = pca.transform(k_means_model.cluster_centers_)

plt.figure(figsize=(7,5))
plt.scatter(X_pca[:,0], X_pca[:,1], c=k_labels, s=40, alpha=0.7)
plt.scatter(centroids_pca[:,0], centroids_pca[:,1],
            c='black', s=200, marker='X', label='Centroids')

plt.title(f"K-Means Clusters (k={k})")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,5))
for lab in np.unique(k_labels):
    mask = k_labels==lab
    plt.scatter(X_pca[mask,0], X_pca[mask,1], s=20, label=f'Cluster {lab}')
plt.title(f'KMeans k={best_k}'); plt.xlabel('PC1'); plt.ylabel('PC2'); plt.legend(); plt.tight_layout(); plt.show()

# %%
k = 5
k_means = KMeans(n_clusters=k, random_state=42, n_init=10)
labels = k_means.fit_predict(X_scaled)

# %%
centroid_table = pd.DataFrame(
    k_means.cluster_centers_,
    columns=data_f.columns
)

print("\n--- Cluster Interpretation Table ---")
print(centroid_table)
# Out:
# --- Cluster Interpretation Table ---
#    Category 1  Category 2  Category 3  Category 4  Category 5  Category 6  \
# 0   -0.301898    0.049441   -0.544324   -0.377000   -0.555976   -0.717286
# 1   -0.125019    0.369775    1.435878    0.129676    0.505115    0.640023
# 2    2.024472   -0.996665   -0.232157   -0.123091   -0.659775   -0.392427
# 3   -0.206013   -0.103948   -0.203861    0.054019    0.623389    0.667066
# 4    0.393918    1.186914   -0.576321    5.557060    0.299038    0.192427
#
#    Category 7  Category 8  Category 9  Category 10
# 0   -0.655845   -0.125861   -0.120702     0.711241
# 1    1.421738   -0.397152    0.019658    -0.982182
# 2   -0.215263    0.218613   -0.292117     0.152443
# 3   -0.086517    0.480952    0.276342    -0.251537
# 4    0.062630   -0.809484   -0.165708    -0.884098

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

eps_list = [0.5, 0.7, 0.9, 1.1, 1.3]
min_samples_list = [3, 4, 5]

results = []

for eps in eps_list:
    for ms in min_samples_list:
        dbscan = DBSCAN(eps=eps, min_samples=ms)
        dbscan_labels = dbscan.fit_predict(X_scaled)

        valid = dbscan_labels != -1
        n_clusters = len(set(dbscan_labels)) - (1 if -1 in dbscan_labels else 0)

        if valid.sum() > 0 and n_clusters > 1:
            dbscan_sil = silhouette_score(X_scaled[valid], dbscan_labels[valid])
        else:
            dbscan_sil_sil = -1  # invalid clustering

        results.append([eps, ms, n_clusters, sil])

results_df = pd.DataFrame(results, 
                          columns=["eps", "min_samples", "Clusters Found", "Silhouette"])

print(results_df)
# Out:
#     eps  min_samples  Clusters Found  Silhouette
# 0   0.5            3               6    0.087811
# 1   0.5            4               1    0.087811
# 2   0.5            5               0    0.087811
# 3   0.7            3              11    0.087811
# 4   0.7            4               3    0.087811
# 5   0.7            5               0    0.087811
# 6   0.9            3              26    0.087811
# 7   0.9            4              13    0.087811
# 8   0.9            5               4    0.087811
# 9   1.1            3              41    0.087811
# 10  1.1            4              23    0.087811
# 11  1.1            5              14    0.087811
# 12  1.3            3              29    0.087811
# 13  1.3            4              16    0.087811
# 14  1.3            5               7    0.087811

# %%
from sklearn.cluster import AgglomerativeClustering

aggloclus = AgglomerativeClustering(n_clusters=5)
agglo_labels = aggloclus.fit_predict(X_scaled)

agglo_sil = silhouette_score(X_scaled, agglo_labels)
print("Agglomerative Silhouette:", agglo_sil)
# Out:
# Agglomerative Silhouette: 0.09567062506285573

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# Perform hierarchical/agglomerative clustering
linked = linkage(X_pca, method='average')  # you already did this

# Plot dendrogram
plt.figure(figsize=(10, 6))
dendrogram(linked,
           orientation='top',   # top-down dendrogram
           distance_sort='ascending',
           show_leaf_counts=True)  # shows how many points in each leaf
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Sample index")
plt.ylabel("Distance")
plt.show()

# %%
comparison = pd.DataFrame({
    "Algorithm": ["K-Means", "DBSCAN", "Agglomerative"],
    "Silhouette Score": [k_sil, dbscan_sil, agglo_sil]
})

print("\n--- ALGORITHM COMPARISON ---")
print(comparison)
# Out:
# --- ALGORITHM COMPARISON ---
#        Algorithm  Silhouette Score
# 0        K-Means          0.159216
# 1         DBSCAN          0.087811
# 2  Agglomerative          0.095671

# %%
kmeans_clust = KMeans(n_clusters=5, random_state=42)
kmeans_clust.fit(X_scaled)

import pickle
pickle.dump(kmeans_clust, open("Downloads/kmeans.pkl", "wb"))
